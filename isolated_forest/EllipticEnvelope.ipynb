# %%
import torch
import pandas as pd
import numpy as np
import sklearn

from sklearn.covariance import EllipticEnvelope
from sklearn.metrics import f1_score, confusion_matrix, classification_report

import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings(action='ignore')

# %%
pd.options.display.float_format = '{:.2f}'.format

# %% [markdown]
# ## Data load

# %%
train = pd.read_csv('../dataset/train.csv')
val = pd.read_csv('../dataset/val.csv')
test = pd.read_csv('../dataset/test.csv')

# %%
val_normal, val_abnormal = val.Class.value_counts()
val_ratio = val_abnormal / val_normal
print(val_normal, val_abnormal, val_ratio)
# Out:
# 28432 30 0.0010551491277433877

# %%
train_x = train.drop(columns=['ID'])

# %%
model = EllipticEnvelope(support_fraction=0.994, contamination=val_ratio, random_state=42)
model.fit(train_x)
# Out:
# EllipticEnvelope(contamination=0.0010551491277433877, random_state=42,
#                  support_fraction=0.994)

# %%
val_x = val.drop(columns=['ID', 'Class'])
val_y = val['Class']

# %%
prob = model.score_samples(val_x)
prob = torch.tensor(prob, dtype=torch.float)
topk_indices = torch.topk(prob, k=30, largest=False).indices

# %%
prob[topk_indices]
# Out:
# tensor([-1.6300e+08, -1.6231e+08, -1.6151e+08, -1.6070e+08, -1.6070e+08,
#         -1.6055e+08, -1.6034e+08, -1.4058e+08, -1.4057e+08, -1.3992e+08,
#         -1.1355e+08, -1.1321e+08, -1.1306e+08, -5.6672e+07, -5.2002e+07,
#         -3.1518e+07, -1.9844e+07, -1.8336e+07, -1.0434e+07, -1.0420e+07,
#         -9.4871e+06, -9.4738e+06, -9.4321e+06, -7.0460e+06, -6.9968e+06,
#         -6.9921e+06, -4.7260e+06, -4.7208e+06, -3.5430e+06, -3.5013e+06])

# %%
prob[topk_indices][-1]
# Out:
# tensor(-3501284.7500)

# %%
-3.5013e+06
# Out:
# -3501300.0

# %%
torch.topk(prob, k=29, largest=False)
# Out:
# torch.return_types.topk(
# values=tensor([-1.6300e+08, -1.6231e+08, -1.6151e+08, -1.6070e+08, -1.6070e+08,
#         -1.6055e+08, -1.6034e+08, -1.4058e+08, -1.4057e+08, -1.3992e+08,
#         -1.1355e+08, -1.1321e+08, -1.1306e+08, -5.6672e+07, -5.2002e+07,
#         -3.1518e+07, -1.9844e+07, -1.8336e+07, -1.0434e+07, -1.0420e+07,
#         -9.4871e+06, -9.4738e+06, -9.4321e+06, -7.0460e+06, -6.9968e+06,
#         -6.9921e+06, -4.7260e+06, -4.7208e+06, -3.5430e+06]),
# indices=tensor([15054, 15345,  4396, 15030, 15029, 15027,  4267,  1196,  1201,   836,
#          1547,  1210,  1047,  3055, 15425, 24358, 25042,  7702, 24742, 15306,
#           677, 12797,   641,  7000, 27998, 25504, 12377, 13706, 24110]))

# %%
pred = torch.zeros(len(val_x), dtype=torch.long)
pred[topk_indices] = 1

# %%
def get_pred(model, x, k) :
    prob = model.score_samples(x)
    prob = torch.tensor(prob, dtype=torch.float)
    topk_indices = torch.topk(prob, k=k, largest=False).indices
    
    pred = torch.zeros(len(x), dtype=torch.int8)
    pred[topk_indices] = 1
    
    return pred.tolist(), prob.tolist()

# %%
val_pred, val_prob = get_pred(model, val_x, 29)

# %%
val_score = f1_score(val_y, val_pred, average='macro')
val_score
# Out:
# 0.9236496787663914

# %%
print(classification_report(val_y, val_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     28432
#            1       0.86      0.83      0.85        30
#
#     accuracy                           1.00     28462
#    macro avg       0.93      0.92      0.92     28462
# weighted avg       1.00      1.00      1.00     28462

# %%
tn, fp, fn, tp = confusion_matrix(val_y, val_pred).ravel()
print('tp : ', tp, ', fp : ', fp, ', tn : ', tn, ', fn : ', fn)
# Out:
# tp :  25 , fp :  4 , tn :  28428 , fn :  5

# %%
confusion_matrix(val_y, val_pred)
# Out:
# array([[28428,     4],
#        [    5,    25]])

# %%
25/30
# Out:
# 0.8333333333333334

# %%
24/28
# Out:
# 0.8571428571428571

# %%
answer = np.where(np.array(val_y) != np.array(val_pred))[0]

# %%
answer.shape
# Out:
# (9,)

# %%
answer
# Out:
# array([   71,  1047,  1210,  4039,  7000,  9326, 14221, 15306, 28146])

# %%
val.iloc[answer, :]
# Out:
#            ID    V1    V2     V3    V4    V5    V6    V7    V8    V9  ...  \
# 71        624 -3.04 -3.16   1.09  2.29  1.36 -1.06  0.33 -0.07 -0.27  ...
# 1047    10457 -1.69  4.08  -7.77  5.57 -3.70 -3.12 -7.85  1.75 -3.27  ...
# 1210    12157 -5.91  6.04 -11.09  5.80 -6.19 -3.32 -9.27  4.34 -3.25  ...
# 4039    40526  1.16  2.84  -4.05  4.78  2.95 -2.01  1.74 -0.41 -2.45  ...
# 7000    70037 -7.45 -3.48  -5.39 -0.06 -4.01 -0.78  0.95  0.53 -0.04  ...
# 9326    93789  1.08  0.96  -0.28  2.74  0.41 -0.32  0.04  0.18 -0.97  ...
# 14221  142558 -1.43 -0.80   1.12  0.39 -0.28 -0.06  1.33  0.20 -0.55  ...
# 15306  153458 -3.14  2.01  -0.61  5.95 -1.87  0.76 -3.31  0.23 -0.94  ...
# 28146  281675  1.99  0.16  -2.58  0.41  1.15 -0.10  0.22 -0.07  0.58  ...
#
#         V22   V23   V24   V25   V26   V27   V28   V29   V30  Class
# 71     0.44  1.38 -0.29  0.28 -0.15 -0.25  0.04  7.08 -0.99      1
# 1047  -0.54 -0.32 -0.02  1.18 -0.21  1.91  0.95 -0.29 -0.79      0
# 1210  -0.43  0.21 -0.03  0.24 -0.29  2.02  0.63  0.95 -0.75      0
# 4039  -0.43 -0.53 -0.60  1.34  0.55  0.01  0.16 -0.29 -0.52      1
# 7000  -1.36 -1.83 -0.34 -0.30 -0.46  1.19 -0.85  8.94 -0.36      0
# 9326  -0.06 -0.05 -0.03  0.40  0.07  0.03  0.06 -0.31 -0.24      1
# 14221  0.01  0.84  0.11  0.16 -0.62 -0.12  0.04  4.64  0.00      1
# 15306  0.80  0.51 -0.05 -0.51  0.44 -0.17  0.68  0.33  0.17      0
# 28146 -0.30 -0.07 -0.45  0.31 -0.29  0.00 -0.02  0.29  1.01      1
#
# [9 rows x 32 columns]

# %%
val.iloc[answer, :]['Class']
# Out:
# 71       1
# 1047     0
# 1210     0
# 4039     1
# 7000     0
# 9326     1
# 14221    1
# 15306    0
# 28146    1
# Name: Class, dtype: int64

# %%
# corr_df = val[val['Class'] == 1].drop(columns=['ID', 'Class']).transpose().corr().round(2)
# corr_df

# %%
# corr_df.style.background_gradient(cmap='coolwarm')

# %%
# tmp_df = pd.concat([val.iloc[[71,4039, 9326, 14221, 28146], :], val.iloc[:25, :]])

# %%
# tmp_df.drop(columns=['ID', 'Class']).transpose().corr().style.background_gradient(cmap='coolwarm')

# %%
tmp_df = pd.concat([val.iloc[answer, :], val[val['Class'] == 1]])
# tmp_df.drop_duplicates()

# %%
tmp_df.drop_duplicates().drop(columns=['Class', 'ID']).transpose().corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_b43c0_row0_col0, #T_b43c0_row1_col1, #T_b43c0_row2_col2, #T_b43c0_row3_col3, #T_b43c0_row4_col4, #T_b43c0_row5_col5, #T_b43c0_row6_col6, #T_b43c0_row7_col7, #T_b43c0_row8_col8, #T_b43c0_row9_col9, #T_b43c0_row10_col10, #T_b43c0_row11_col11, #T_b43c0_row12_col12, #T_b43c0_row12_col13, #T_b43c0_row13_col12, #T_b43c0_row13_col13, #T_b43c0_row14_col14, #T_b43c0_row15_col15, #T_b43c0_row16_col16, #T_b43c0_row17_col17, #T_b43c0_row18_col18, #T_b43c0_row19_col19, #T_b43c0_row20_col20, #T_b43c0_row21_col21, #T_b43c0_row22_col22, #T_b43c0_row23_col23, #T_b43c0_row23_col24, #T_b43c0_row24_col23, #T_b43c0_row24_col24, #T_b43c0_row25_col25, #T_b43c0_row26_col26, #T_b43c0_row27_col27, #T_b43c0_row28_col28, #T_b43c0_row29_col29, #T_b43c0_row30_col30, #T_b43c0_row31_col31, #T_b43c0_row32_col32, #T_b43c0_row33_col33 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_b43c0_row0_col1 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_b43c0_row0_col2, #T_b43c0_row8_col25, #T_b43c0_row33_col0 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_b43c0_row0_col3, #T_b43c0_row1_col6, #T_b43c0_row16_col6, #T_b43c0_row21_col6 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_b43c0_row0_col4, #T_b43c0_row2_col28, #T_b43c0_row7_col26, #T_b43c0_row19_col11, #T_b43c0_row22_col19, #T_b43c0_row29_col18, #T_b43c0_row30_col11, #T_b43c0_row32_col2, #T_b43c0_row32_col13, #T_b43c0_row33_col16 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_b43c0_row0_col5, #T_b43c0_row4_col10, #T_b43c0_row4_col21, #T_b43c0_row6_col5, #T_b43c0_row6_col7, #T_b43c0_row12_col6, #T_b43c0_row25_col3 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_b43c0_row0_col6, #T_b43c0_row15_col21, #T_b43c0_row17_col11, #T_b43c0_row21_col22, #T_b43c0_row27_col33, #T_b43c0_row31_col23, #T_b43c0_row31_col24, #T_b43c0_row33_col21 {
#   background-color: #f39475;
#   color: #000000;
# }
# #T_b43c0_row0_col7, #T_b43c0_row2_col6, #T_b43c0_row17_col6, #T_b43c0_row20_col0, #T_b43c0_row20_col3 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_b43c0_row0_col8, #T_b43c0_row8_col13, #T_b43c0_row17_col0, #T_b43c0_row23_col0, #T_b43c0_row24_col0, #T_b43c0_row32_col6 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_b43c0_row0_col9, #T_b43c0_row0_col21 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_b43c0_row0_col10, #T_b43c0_row0_col20, #T_b43c0_row3_col0, #T_b43c0_row17_col8 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_b43c0_row0_col11, #T_b43c0_row5_col14, #T_b43c0_row16_col3 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_b43c0_row0_col12, #T_b43c0_row0_col13, #T_b43c0_row5_col23, #T_b43c0_row5_col24, #T_b43c0_row14_col0, #T_b43c0_row25_col0 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_b43c0_row0_col14 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_b43c0_row0_col15, #T_b43c0_row5_col27, #T_b43c0_row17_col3 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_b43c0_row0_col16, #T_b43c0_row5_col2 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_b43c0_row0_col17, #T_b43c0_row3_col20, #T_b43c0_row8_col4, #T_b43c0_row10_col6 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_b43c0_row0_col18 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_b43c0_row0_col19, #T_b43c0_row0_col33 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_b43c0_row0_col22, #T_b43c0_row3_col25 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_b43c0_row0_col23, #T_b43c0_row0_col24, #T_b43c0_row3_col14 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_b43c0_row0_col25, #T_b43c0_row8_col2 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_b43c0_row0_col26, #T_b43c0_row7_col8 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_b43c0_row0_col27 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_b43c0_row0_col28 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_b43c0_row0_col29, #T_b43c0_row15_col6, #T_b43c0_row27_col6 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_b43c0_row0_col30, #T_b43c0_row22_col6 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_b43c0_row0_col31, #T_b43c0_row14_col3, #T_b43c0_row19_col0 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_b43c0_row0_col32, #T_b43c0_row5_col26, #T_b43c0_row31_col6, #T_b43c0_row32_col0 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_b43c0_row1_col0, #T_b43c0_row3_col11, #T_b43c0_row8_col11, #T_b43c0_row15_col0, #T_b43c0_row27_col3, #T_b43c0_row30_col3, #T_b43c0_row33_col6 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_b43c0_row1_col2, #T_b43c0_row2_col1, #T_b43c0_row2_col11, #T_b43c0_row9_col10, #T_b43c0_row11_col2 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_b43c0_row1_col3, #T_b43c0_row14_col5 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_b43c0_row1_col4, #T_b43c0_row3_col29, #T_b43c0_row9_col18, #T_b43c0_row10_col16, #T_b43c0_row25_col10, #T_b43c0_row33_col3 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_b43c0_row1_col5 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_b43c0_row1_col7, #T_b43c0_row2_col14, #T_b43c0_row2_col17, #T_b43c0_row12_col27, #T_b43c0_row15_col17, #T_b43c0_row15_col18, #T_b43c0_row18_col1, #T_b43c0_row27_col12, #T_b43c0_row30_col16 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_b43c0_row1_col8, #T_b43c0_row6_col18, #T_b43c0_row22_col8, #T_b43c0_row23_col8, #T_b43c0_row24_col8, #T_b43c0_row28_col0 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_b43c0_row1_col9, #T_b43c0_row5_col10, #T_b43c0_row11_col30, #T_b43c0_row12_col21, #T_b43c0_row14_col7, #T_b43c0_row21_col13, #T_b43c0_row30_col25 {
#   background-color: #f7a889;
#   color: #000000;
# }
# #T_b43c0_row1_col10, #T_b43c0_row2_col10, #T_b43c0_row2_col32, #T_b43c0_row6_col0, #T_b43c0_row10_col13, #T_b43c0_row11_col32, #T_b43c0_row13_col18, #T_b43c0_row19_col1, #T_b43c0_row21_col12, #T_b43c0_row21_col23, #T_b43c0_row21_col24, #T_b43c0_row26_col15, #T_b43c0_row31_col15, #T_b43c0_row32_col1 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_b43c0_row1_col11, #T_b43c0_row11_col1, #T_b43c0_row22_col23, #T_b43c0_row22_col24, #T_b43c0_row23_col22, #T_b43c0_row24_col22 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_b43c0_row1_col12, #T_b43c0_row1_col21, #T_b43c0_row12_col29, #T_b43c0_row19_col29, #T_b43c0_row20_col15, #T_b43c0_row21_col1, #T_b43c0_row27_col18, #T_b43c0_row28_col10, #T_b43c0_row30_col22 {
#   background-color: #ec8165;
#   color: #f1f1f1;
# }
# #T_b43c0_row1_col13, #T_b43c0_row2_col21, #T_b43c0_row3_col9, #T_b43c0_row18_col30, #T_b43c0_row21_col10, #T_b43c0_row21_col33, #T_b43c0_row23_col26, #T_b43c0_row24_col26, #T_b43c0_row25_col14, #T_b43c0_row27_col30, #T_b43c0_row28_col9, #T_b43c0_row31_col22 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_b43c0_row1_col14, #T_b43c0_row1_col30, #T_b43c0_row13_col32, #T_b43c0_row14_col1, #T_b43c0_row19_col22, #T_b43c0_row20_col21, #T_b43c0_row20_col28, #T_b43c0_row21_col20, #T_b43c0_row22_col28, #T_b43c0_row29_col16, #T_b43c0_row31_col3, #T_b43c0_row31_col27, #T_b43c0_row32_col11 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_b43c0_row1_col15, #T_b43c0_row12_col23, #T_b43c0_row12_col24, #T_b43c0_row13_col23, #T_b43c0_row13_col24, #T_b43c0_row16_col17, #T_b43c0_row23_col14, #T_b43c0_row24_col14, #T_b43c0_row27_col2, #T_b43c0_row32_col10 {
#   background-color: #ca3b37;
#   color: #f1f1f1;
# }
# #T_b43c0_row1_col16, #T_b43c0_row20_col2, #T_b43c0_row21_col19, #T_b43c0_row30_col17 {
#   background-color: #e36b54;
#   color: #f1f1f1;
# }
# #T_b43c0_row1_col17, #T_b43c0_row1_col32, #T_b43c0_row10_col5, #T_b43c0_row18_col4, #T_b43c0_row18_col7, #T_b43c0_row18_col13, #T_b43c0_row27_col20, #T_b43c0_row27_col21, #T_b43c0_row33_col12 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_b43c0_row1_col18, #T_b43c0_row2_col29, #T_b43c0_row13_col27, #T_b43c0_row14_col2, #T_b43c0_row16_col1, #T_b43c0_row27_col13, #T_b43c0_row29_col11 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_b43c0_row1_col19, #T_b43c0_row11_col10, #T_b43c0_row15_col26, #T_b43c0_row19_col2, #T_b43c0_row19_col5, #T_b43c0_row19_col20, #T_b43c0_row28_col26 {
